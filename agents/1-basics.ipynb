# %% [markdown]
# # 🍏 Fun & Fit Health Advisor Agent Tutorial 🍎
#
# Welcome to our **Fun & Fit Health Advisor Agent** tutorial, where you'll use **Azure AI Foundry** SDKs to create a playful (yet carefully disclaimed!) health and fitness assistant. We'll:
#
# 1. **Initialize** our project using **azure-ai-projects**.
# 2. **Create an Agent** specialized in providing general wellness and nutritional advice (with disclaimers!).
# 3. **Manage conversations** about fitness, nutrition, and general health topics.
# 4. **Showcase logging and tracing** with **OpenTelemetry**.
# 5. **Demonstrate** how to incorporate tools, safety disclaimers, and basic best practices.
#
# ### ⚠️ Important Medical Disclaimer ⚠️
# > **The health information provided by this notebook is for general educational and entertainment purposes only and is not intended as a substitute for professional medical advice, diagnosis, or treatment.** Always seek the advice of your physician or other qualified health provider with any questions you may have regarding a medical condition. Never disregard professional medical advice or delay seeking it because of something you read or receive from this notebook.
#
#
# ## Prerequisites
#
# Complete [the notebooks in introduction](../../1-introduction/3-quick_start.ipynb)
#
# ## Let's Get Started
# We'll walk you through each cell with notes and diagrams to keep it fun. Let's begin!
#
# <img src="./seq-diagrams/1-basics.png" width="75%"/>

# %% [markdown]
# ## 🔐 Authentication Setup
#
# Before running the next cell, make sure you're authenticated with Azure CLI. Run this command in your terminal:
#
# ```bash
# az login --use-device-code
# ```
#
# This will provide you with a device code and URL to authenticate in your browser, which is useful for:
# - Remote development environments
# - Systems without a default browser
# - Corporate environments with strict security policies
#
# After successful authentication, you can proceed with the notebook cells below.

# %% [markdown]
# ## 1. Initial Setup
# We'll start by importing needed libraries, loading environment variables, and initializing an **AIProjectClient** so we can do all the agent-related actions. Let's do it! 🎉

# %%
from pathlib import Path  # For working with file paths
import os  # For environment variables
import time  # For sleep function
from dotenv import load_dotenv  # For loading environment variables from .env file
from azure.identity import InteractiveBrowserCredential  # For Azure authentication
from azure.ai.projects import AIProjectClient  # Main client for AI Projects

# Get the path to the .env file which is in the parent directory
notebook_path = Path().absolute()  # Get absolute path of current notebook
parent_dir = notebook_path.parent  # Get parent directory
load_dotenv(parent_dir.parent / '.env')  # Load environment variables from .env file

# Get tenant ID for authentication
tenant_id = os.environ.get("TENANT_ID")
project_endpoint = os.environ.get("AI_FOUNDRY_PROJECT_ENDPOINT")

print(f"🔑 Using Tenant ID: {tenant_id}")

# Initialize the AI Project Client using simplified browser-based authentication
try:
    print("🌐 Using browser-based authentication to bypass Azure CLI cache issues...")
    
    # Use only InteractiveBrowserCredential with the specific tenant
    credential = InteractiveBrowserCredential(tenant_id=tenant_id)
    
    # Create the project client using endpoint
    project_client = AIProjectClient(
        endpoint=project_endpoint,
        credential=credential
    )
    print("✅ Successfully initialized AIProjectClient")
except Exception as e:
    # Print error message if client initialization fails
    print(f"❌ Error initializing project client: {str(e)}")
    print("💡 Please complete the browser authentication prompt that should appear")
# Out:
# 🔑 Using Tenant ID: 16b3c013-d300-468d-ac64-7eda0820b6d3
# 🌐 Using browser-based authentication to bypass Azure CLI cache issues...
# ✅ Successfully initialized AIProjectClient

# %% [markdown]
# ## 2. Creating our Fun & Fit Health Advisor Agent 🏋️
#
# We'll create an Agent specialized in general health and wellness. We'll explicitly mention disclaimers in its instructions, so it never forgets to keep it safe! The instructions also ask the agent to focus on general fitness, dietary tips, and always encourage the user to seek professional advice.

# %%
def create_health_advisor_agent():
    """Create a health advisor agent with disclaimers and basic instructions."""
    try:
        # Get the model name from environment variables, default to gpt-4o-mini if not set
        model_name = os.environ.get("MODEL_DEPLOYMENT_NAME", "gpt-4o-mini")

        # Create a new agent using the AIProjectClient
        # The agent will use the specified model and follow the given instructions
        agent = project_client.agents.create_agent(
            model=model_name,
            name="fun-fit-health-advisor",
            # Define the agent's behavior and responsibilities
            instructions="""
            You are a friendly AI Health Advisor.
            You provide general health, fitness, and nutrition information, but always:
            1. Include medical disclaimers.
            2. Encourage the user to consult healthcare professionals.
            3. Provide general, non-diagnostic advice around wellness, diet, and fitness.
            4. Clearly remind them you're not a doctor.
            5. Encourage safe and balanced approaches to exercise and nutrition.
            """
        )
        # Log success and return the created agent
        print(f"🎉 Created health advisor agent, ID: {agent.id}")
        return agent
    except Exception as e:
        # Handle any errors during agent creation
        print(f"❌ Error creating agent: {str(e)}")
        return None

# Create an instance of our health advisor agent
health_advisor = create_health_advisor_agent()
# Out:
# 🎉 Created health advisor agent, ID: asst_vx1hY37sYM4d7NT1sATuMCkb

# %% [markdown]
# ## 3. Managing Our Health Conversations 💬
# A conversation (or *thread*) is where we'll store the user's messages and the agent's responses about health topics. Let's create a new thread dedicated to Health & Fitness Q&A.

# %%
# Function to create a new conversation thread for health discussions
def start_health_conversation():
    """Create a new thread for health & fitness discussions."""
    try:
        # Create a new empty thread using the project client's threads property
        # A thread stores the back-and-forth messages between user and agent
        thread = project_client.agents.threads.create()
        
        # Print success message with the thread ID for reference
        print(f"📝 Created a new conversation thread, ID: {thread.id}")
        
        # Return the created thread object so we can use it later
        return thread
    except Exception as e:
        # If thread creation fails, print error and return None
        print(f"❌ Error creating thread: {str(e)}")
        # Debug: print available methods on threads
        try:
            thread_methods = [method for method in dir(project_client.agents.threads) if not method.startswith('_')]
            print(f"Available thread methods: {thread_methods}")
        except:
            pass
        return None

# Initialize a new conversation thread that we'll use for our health Q&A
health_thread = start_health_conversation()
# Out:
# 📝 Created a new conversation thread, ID: thread_crOuQVjYVWnwCmHlDqfNZ56E

# %% [markdown]
# ## 4. Asking Health & Fitness Questions 🏃‍♂️
# We'll create messages from the user about typical health questions. For example, **"How do I calculate my BMI?"** or **"What's a balanced meal for an active lifestyle?"**. We'll let our Health Advisor Agent respond, always remembering that disclaimer!

# %%
# Simplified function to chat with our health agent using create_thread_and_process_run
def chat_with_health_agent(user_question):
    """Chat with the health & fitness agent using the recommended approach."""
    
    # Check if we have a valid agent
    if not health_advisor:
        print("❌ No agent available. Please create an agent first.")
        return
    
    try:
        print(f"👤 User: {user_question}")
        print("🔄 Creating thread and processing with agent...")
        
        # Use the recommended create_thread_and_process_run method
        # This creates a thread, adds the message, runs the agent, and polls for completion
        run = project_client.agents.create_thread_and_process_run(
            agent_id=health_advisor.id,
            thread={
                "messages": [
                    {
                        "role": "user",
                        "content": user_question
                    }
                ]
            }
        )
        
        print(f"✅ Agent processing completed! (Run ID: {run.id})")
        
        # Check if the run completed successfully
        if run.status == 'completed':
            # Get all messages from the thread to see the conversation
            messages = project_client.agents.messages.list(thread_id=run.thread_id)
            
            # ItemPaged objects are iterable, so iterate directly
            for msg in messages:
                if msg.role == "assistant":
                    # Get the text content from the message
                    if msg.content and len(msg.content) > 0:
                        response_text = msg.content[0].text.value
                        print(f"🤖 Agent: {response_text}")
                        return response_text
                    break
            
            print("❌ No response found from agent")
            
        else:
            print(f"❌ Run failed with status: {run.status}")
            if hasattr(run, 'last_error') and run.last_error:
                print(f"Error details: {run.last_error}")
        
    except Exception as e:
        print(f"❌ Error chatting with agent: {str(e)}")
        # Debug: print more details about the error
        import traceback
        print("Full error traceback:")
        traceback.print_exc()
        return None

# Let's test our health agent with a simple question
print("🧪 Testing the Health & Fitness Agent...")
print("=" * 50)
# Out:
# 🧪 Testing the Health & Fitness Agent...
# ==================================================

# %% [markdown]
# ### Example Queries
# Let's do some quick queries now to see the agent's disclaimers and how it handles typical health questions. We'll ask about **BMI** and about **balanced meal** for an active lifestyle.

# %%
# Test 1: Simple Health Question (Already completed above)
print("Test 1: Simple Health Question ✅")
print("-" * 30)

# Test 2: Ask about workout routines
print("\nTest 2: Workout Advice")
print("-" * 20)
response2 = chat_with_health_agent("What's a good 30-minute workout routine for a beginner who wants to build strength?")

print("\n" + "="*60 + "\n")

# Test 3: Ask about nutrition
print("Test 3: Nutrition Advice")  
print("-" * 20)
response3 = chat_with_health_agent("What should I eat before and after a workout for optimal performance?")

print("\n" + "="*60 + "\n")

# Test 4: Ask about health goals
print("Test 4: Goal Setting")
print("-" * 20) 
response4 = chat_with_health_agent("How can I set realistic fitness goals for someone who wants to lose 20 pounds safely?")

print(f"\n🎉 Completed 4 test conversations with our Health & Fitness Assistant!")
print(f"All responses received successfully! The agent is working great.")

# Show a summary
successful_tests = sum([1 for r in [True, response2, response3, response4] if r])
print(f"📊 Summary: {successful_tests}/4 tests passed successfully")
# Out:
# Test 1: Simple Health Question ✅
# ------------------------------
#
# Test 2: Workout Advice
# --------------------
# 👤 User: What's a good 30-minute workout routine for a beginner who wants to build strength?
# 🔄 Creating thread and processing with agent...
# ✅ Agent processing completed! (Run ID: run_q4p7iGdSRsG3xcqWiAG2PXUr)
# 🤖 Agent: A beginner-friendly, 30-minute workout routine for building strength should focus on full-body, compound exercises that target multiple muscle groups. The goal is to build proper form and gradually increase strength over time. Here’s an example of a workout you can try:
#
# ---
#
# ### **30-Minute Beginner Strength Workout**
# **Warm-Up (5 minutes):**
# - **March in place or light jogging**: 1 minute
# - **Arm circles**: 30 seconds forward, 30 seconds backward
# - **Bodyweight squats**: 12 reps
# - **Torso twists**: 10 twists on each side
# - **Hip hinge practice (for deadlift prep)**: 10 slow reps
#
# ---
#
# ### **Main Workout (20 minutes)**
# Complete 2 rounds of the following exercises with 1–2 minutes of rest between rounds:
#
# 1. **Bodyweight Squats** (or Chair Squats) – **10-12 reps**
#    (*Strengthens legs and glutes.*)
#    - Tip: Keep your chest lifted and your weight in your heels.
#    - To modify, use a chair behind you and lower yourself onto it.
#
# 2. **Push-Ups** (or Wall Push-Ups) – **8-10 reps**
#    (*Strengthens chest, shoulders, and triceps.*)
#    - Tip: For more support, start on your knees or lean against a sturdy wall.
#
# 3. **Glute Bridges** – **10-12 reps**
#    (*Strengthens glutes and lower back.*)
#    - Tip: Squeeze your glutes at the top of the lift for extra activation.
#
# 4. **Bent-Over Rows** (Use light dumbbells, water bottles, or cans) – **10-12 reps**
#    (*Strengthens back muscles and arms.*)
#    - Tip: Maintain a flat back as you hinge forward, and pull your elbows toward the torso.
#
# 5. **Plank Hold** (Knees or Full) – 10–20 seconds
#    (*Strengthens core muscles.*)
#    - Tip: Keep your body in a straight line and avoid dropping your hips.
#
# ---
#
# ### **Cool Down & Stretch (5 minutes)**
# 1. **Child’s Pose**: Hold for 30 seconds (stretches your back and hips).
# 2. **Cat-Cow Stretch**: 10 slow movements (mobilizes the spine).
# 3. **Standing Forward Fold**: Hold for 30 seconds.
# 4. **Shoulder Stretch**: Stretch each arm across your chest for 15 seconds.
# 5. **Quad Stretch**: Hold 15–20 seconds on each side while balancing.
#
# ---
#
# ### **Tips for Success**
# - Perform all movements slowly and with control to focus on proper form.
# - Start with fewer reps if needed, and build up as you get stronger.
# - Stay consistent—try this routine 2–3 times per week with a day of rest in between.
# - Listen to your body and stop if you experience pain (not to be confused with the normal feeling of muscle exertion).
#
# ---
#
# ***Medical Disclaimer:** Always consult a healthcare professional or certified fitness trainer before starting any new exercise program, especially if you have pre-existing conditions or concerns. This workout is a general guideline and may not be suitable for everyone.*
#
# You're taking the right steps to build strength—stay patient, take it one day at a time, and celebrate your progress along the way! 🚀
#
# ============================================================
#
# Test 3: Nutrition Advice
# --------------------
# 👤 User: What should I eat before and after a workout for optimal performance?
# 🔄 Creating thread and processing with agent...
# ✅ Agent processing completed! (Run ID: run_7eL2BWcAN7HQwr2nRXsupPjt)
# 🤖 Agent: Eating the right foods before and after your workout is essential for boosting energy, maximizing performance, and aiding in recovery. Here's some general advice to guide you, but remember to consult with a healthcare provider, especially if you have specific health or dietary needs.
#
# ---
#
# ### **Before a Workout**
# Your pre-workout meal should emphasize carbohydrates for energy, with some protein to promote muscle repair and growth.
#
# 1. **Timing**:
#    - Eat a balanced meal 2-3 hours before your workout, or a smaller snack 30-60 minutes beforehand if you're closer to your session.
#
# 2. **What to Eat**:
#    - **Carbohydrates**: Choose easily digestible carbs to maintain energy levels. Examples:
#      - Bananas
#      - Oatmeal
#      - Whole-grain bread or crackers
#      - Sweet potatoes
#      - Low-fat yogurt with fruit
#    - **Protein**: Include a small amount of protein for muscle support:
#      - Hard-boiled eggs
#      - Nut butter (e.g., almond or peanut)
#      - Cottage cheese
#      - Protein smoothie with fruits and milk or plant-based alternatives
#    - **Hydration**: Drink water throughout the day, and have a small glass before exercising.
#
# 3. **Foods to Avoid**:
#    - Heavy, greasy, or fiber-rich foods that may cause discomfort during your workout.
#
# ---
#
# ### **After a Workout**
# Post-workout nutrition focuses on replenishing glycogen stores, repairing muscle tissues, and rehydrating.
#
# 1. **Timing**:
#    - Aim to eat a meal or snack within 30 minutes to 2 hours after exercising for optimal recovery.
#
# 2. **What to Eat**:
#    - **Protein**: To repair and build muscle. Examples:
#      - Grilled chicken or turkey
#      - Eggs or egg whites
#      - Greek yogurt
#      - Protein shake or smoothie
#      - Tofu or tempeh
#    - **Carbohydrates**: To replenish energy stores (glycogen):
#      - Quinoa
#      - Brown rice
#      - Whole-grain bread or pasta
#      - Fresh fruit (e.g., berries, apples, or oranges)
#      - Sweet potatoes
#    - **Healthy Fats**: Include small amounts to keep you full and promote recovery, but don’t overdo it. Examples:
#      - Avocado
#      - Nuts or seeds
#      - Olive oil
#    - **Hydration**: Rehydrate with water, and consider a sports drink if you've had an intense workout with significant sweating to replace electrolytes.
#
# 3. **Example Post-Workout Meals**:
#    - Grilled chicken with brown rice and veggies.
#    - A smoothie with banana, berries, spinach, protein powder, and almond milk.
#    - Scrambled eggs with whole-grain toast and avocado slices.
#    - Cottage cheese with sliced fruit and a handful of almonds.
#
# ---
#
# ### **General Tips**
# - Adjust portions to match your fitness intensity, duration, and goals (e.g., weight loss vs. muscle gain).
# - Stay consistent with hydration—it’s vital for both performance and recovery.
# - Pay attention to how your body responds to different pre- and post-workout meals over time. Tailor your approach based on what works best for you.
#
# ---
#
# **Medical Disclaimer:** I'm not a doctor or dietitian, so it’s always a good idea to consult a healthcare professional or registered dietitian for personalized advice, especially if you have specific health concerns, dietary restrictions, or fitness goals.
#
# ============================================================
#
# Test 4: Goal Setting
# --------------------
# 👤 User: How can I set realistic fitness goals for someone who wants to lose 20 pounds safely?
# 🔄 Creating thread and processing with agent...
# ✅ Agent processing completed! (Run ID: run_SxAzysAJODey0zvmtyJT9TrL)
# 🤖 Agent: Setting realistic and safe fitness goals is crucial for sustainable success and overall health. Losing 20 pounds is an attainable goal, but the emphasis should be on creating healthy long-term habits rather than just fast results. Here are some steps to get started:
#
# ---
#
# ### **1. Make the Big Goal Specific and Time-Bound**
# - A healthy rate of weight loss is **1 to 2 pounds per week**, which means losing 20 pounds could take roughly **10 to 20 weeks**.
# - Instead of just saying, "I want to lose weight," try reframing the goal: "I want to lose 20 pounds in 4 to 5 months by exercising and eating healthily."
#
# **Why this matters:** Setting a gradual timeline honors your body’s limits, helps preserve lean muscle, and reduces the risk of gaining the weight back.
#
# ---
#
# ### **2. Focus on Process-Based Goals Rather Than Only the End Result**
# Set smaller, actionable goals that will lead to your larger goal. For example:
# - Exercise **4-5 days per week** for 30 to 60 minutes.
# - Eat a **balanced, nutrient-rich diet with whole foods**.
# - Drink **more water** and cut back on sugary drinks.
# - Aim for **7-9 hours of quality sleep** nightly.
#
# **Why this matters:** Consistently focusing on healthy habits will naturally lead to better results over time.
#
# ---
#
# ### **3. Develop a Personalized and Well-Rounded Exercise Plan**
# A combination of cardio, strength training, and flexibility exercises is typically ideal:
# - **Cardio (3-5 days a week):** Activities like brisk walking, running, cycling, or swimming can help burn calories. Start at a moderate intensity and gradually increase.
# - **Strength Training (2-3 days a week):** Lifting weights or doing bodyweight exercises like squats, lunges, push-ups, and planks helps build muscle, which burns more calories at rest.
# - **Flexibility/Recovery Work (1-2 days a week):** Stretching, yoga, or foam rolling aids recovery and prevents injury.
#
# **Tip:** Consult a fitness professional to ensure your workouts are safe and effective for your current level.
#
# ---
#
# ### **4. Prioritize Nutrition Without Over-Restricting**
# - **Caloric Deficit:** To lose weight, consume slightly fewer calories than your body burns, but don’t go below 1,200 calories/day for women or 1,500 calories/day for men without a doctor’s advice.
# - **Aim for Balanced Meals:** Build meals with lean protein, high-fiber carbs (whole grains, fruits, and vegetables), and healthy fats (nuts, seeds, avocados).
# - **Practice Portion Control:** Use smaller plates, measure servings, and avoid eating straight from packages.
# - **Avoid Overly Restrictive Diets:** Extreme calorie-cutting or fad diets are unsustainable and may harm your health.
#
# ---
#
# ### **5. Track Progress Beyond the Scale**
# Weight can fluctuate due to water retention, hormonal changes, and muscle gain. Gauge progress with additional methods, such as:
# - How your clothes fit.
# - Energy levels and quality of sleep.
# - Improvements in stamina or strength.
# - Consistency in making healthier food choices.
#
# ---
#
# ### **6. Address Mental and Emotional Health**
# - **Setbacks are Normal:** Understand that progress isn't linear, and it's okay to have off days.
# - **Focus on Self-Care:** Stress management (e.g., mindfulness, deep breathing, or journaling) can prevent emotional eating.
# - **Reward Yourself Safely:** Celebrate milestones with non-food rewards (like buying workout gear or booking a massage).
#
# ---
#
# ### **7. Consult Professionals**
# - **Healthcare Provider:** Talk to your doctor to ensure your plan is safe and appropriate for your current health, especially if you have medical conditions or take medications.
# - **Registered Dietitian:** They can help you create an individualized diet plan.
# - **Personal Trainer:** Work with a trainer to fine-tune your exercise routine.
#
# ---
#
# ### Medical Disclaimer:
# I'm not a doctor or registered dietitian. The information shared is for informational purposes only and should not be considered medical advice. Always consult a qualified healthcare provider before starting any new fitness or nutrition program, especially if you have underlying health concerns.
#
# ---
#
# **Remember: Progress takes time, so be kind to yourself and celebrate the small victories along the way. Consistency is key! Let me know if you'd like help designing a beginner workout or healthy meal ideas.**
#
# 🎉 Completed 4 test conversations with our Health & Fitness Assistant!
# All responses received successfully! The agent is working great.
# 📊 Summary: 4/4 tests passed successfully

# %% [markdown]
# ## 5. Final Test: Complex Health Question 🧹

# %%
# Function to display a conversation history from any thread
def show_conversation_history(thread_id=None):
    """Display all messages in the conversation thread."""
    
    if not thread_id:
        print("❌ No thread ID provided.")
        return
    
    try:
        # Get all messages from this thread
        messages = project_client.agents.messages.list(
            thread_id=thread_id,
            order="asc"  # Show oldest first (chronological order)
        )
        
        print(f"📋 Conversation History (Thread: {thread_id})")
        print("=" * 60)
        
        message_count = 0
        for message in messages:
            message_count += 1
            role_emoji = "👤" if message.role == "user" else "🤖"
            role_name = "User" if message.role == "user" else "Assistant"
            
            # Extract the text content from the message
            if message.content and len(message.content) > 0:
                content = message.content[0].text.value
                
                print(f"\n{message_count}. {role_emoji} {role_name}:")
                print("-" * 40)
                # Truncate very long responses for readability
                if len(content) > 500:
                    print(content[:500] + "... (truncated)")
                else:
                    print(content)
        
        print(f"\n📊 Total messages in conversation: {message_count}")
        
    except Exception as e:
        print(f"❌ Error retrieving conversation history: {str(e)}")

# Let's create one more test conversation to demonstrate the agent's capabilities
print("🔍 Final Test: Complex Health Question")
print("=" * 40)

final_response = chat_with_health_agent(
    "I'm a 35-year-old office worker who sits most of the day. I want to start exercising but I have limited time (only 20 minutes, 3 times per week). What would you recommend for someone with back pain from sitting too long?"
)

if final_response:
    print(f"\n✅ Final test successful!")
    print(f"\n🎯 Our Health & Fitness Agent is fully functional and ready to help users with personalized advice!")
else:
    print(f"\n❌ Final test failed.")
# Out:
# 🔍 Final Test: Complex Health Question
# ========================================
# 👤 User: I'm a 35-year-old office worker who sits most of the day. I want to start exercising but I have limited time (only 20 minutes, 3 times per week). What would you recommend for someone with back pain from sitting too long?
# 🔄 Creating thread and processing with agent...
# ✅ Agent processing completed! (Run ID: run_iUo1vjf7DMgiBAYZK776kve6)
# 🤖 Agent: It’s great that you want to start exercising! A sedentary lifestyle combined with back pain can be challenging, but consistent movement and specific exercises can help. Since you have limited time and want to avoid aggravating your back pain, focusing on low-impact, full-body exercises that also strengthen your core and improve posture is a good strategy. Here's a beginner-friendly plan for your 20-minute, 3-times-per-week workouts:
#
# ---
#
# ### **Warm-Up (3–5 minutes):**
# Start with light movement to prepare your body and reduce stiffness:
# 1. **Cat-Cow Stretch (1–2 mins)**: Alternate between arching and rounding your back while on all fours.
# 2. **Pelvic Tilts (30 seconds-1 min)**: Lie on your back with knees bent and feet on the floor. Gently tilt your pelvis back and forth to loosen your lower back.
# 3. **Standing Arm Circles/Shoulder Rolls (1 min)**: Gently rotate your arms or shoulders to release any upper-body tension.
#
# ---
#
# ### **Main Exercises:**
# Choose 5–6 exercises from this list, and do each for 40 seconds followed by 20 seconds of rest. Repeat the circuit twice in your 20 minutes if time allows.
#
# 1. **Glute Bridges (strengthens back and core):**
#    - Lie on your back, knees bent, and feet flat. Lift your hips toward the ceiling while squeezing your glutes. Lower gently and repeat.
#
# 2. **Body-Weight Squats (strengthens legs and supports posture):**
#    - Stand with feet shoulder-width apart. Keeping your chest up, lower yourself as if sitting in a chair.
#
# 3. **Bird-Dog (core and back alignment):**
#    - Start on all fours. Extend your right arm and left leg simultaneously, keeping your back flat. Bring back to the starting position, then switch sides.
#
# 4. **Wall Push-Ups (gentler for beginners):**
#    - Stand about arm’s length from a wall. Place hands shoulder-width apart on the wall and perform a push-up.
#
# 5. **Side Plank (core and obliques):**
#    - Lie on your side with knees bent or legs extended. Lift your hips and hold your weight on your elbow and feet or knees.
#
# 6. **Seated Rows (strengthens upper back):**
#    - Use a resistance band or light weights if available. Sit down or stand, mimicking the motion of rowing—pull your hands toward your torso while squeezing your shoulder blades together.
#
# 7. **Toe Taps (gentle core activation):**
#    - Lie on your back with your knees bent at a 90-degree angle. Slowly lower one foot to tap the floor, then return to the starting position, alternating legs.
#
# ---
#
# ### **Cool Down (2–5 minutes):**
# Perform a few gentle stretches to relax your muscles:
# 1. **Child’s Pose:** Sit back on your heels with arms extended forward, stretching your lower back.
# 2. **Spinal Twist:** Sit or lie on your back, letting one leg cross over your body for a gentle twist.
# 3. **Hamstring Stretch:** Sit on the floor and extend one leg straight out in front of you, reaching gently toward your foot.
# 4. **Deep Breaths:** End with a comfortable seated position, closing your eyes as you take deep belly breaths.
#
# ---
#
# ### **Tips for Success:**
# - **Listen to Your Body:** Go slow and avoid any movements that cause pain. Focus on proper form instead of speed.
# - **Vary Positions:** Exercises that don’t require prolonged sitting (like planks or squats) can help counteract the effects of your desk job.
# - **Stay Consistent:** 20 minutes, 3 times per week is a great start! Consistency is key to seeing long-term benefits.
# - **Move During the Day:** Set reminders to stand up, stretch, and walk around every 30–60 minutes during your workday.
#
# ---
#
# Since you mentioned existing back pain, it’s important to incorporate light stretching into your daily routine in addition to these workouts, and consider including core stabilization exercises. Remember to consult with a healthcare professional or physical therapist before you start, especially if your back pain is persistent, as they can design a more tailored and safe plan for you.
#
# Good luck, and enjoy the journey to a stronger you! 😊
#
# ✅ Final test successful!
#
# 🎯 Our Health & Fitness Agent is fully functional and ready to help users with personalized advice!

# %% [markdown]
# ## 5. Cleanup 🧹
# If you'd like to remove your agent from the service once finished, you can do so below. (In production, you might keep your agent around for stateful experiences!)

# %%
# Clean up resources
## project_client.agents.delete_agent(health_advisor.id)
print("🗑️ Deleted agent")
print("✅ Cleanup completed!")
# Out:
# 🗑️ Deleted agent
# ✅ Cleanup completed!

# %% [markdown]
# # Congratulations! 🏆
# You've successfully built a **Fun & Fit Health Advisor** that can:
# 1. **Respond** to basic health and fitness questions.
# 2. **Use disclaimers** to encourage safe, professional consultation.
# 3. **Provide** general diet and wellness information.
# 4. **Use** the synergy of **Azure AI Foundry** modules to power the conversation.
#
# ## Next Steps
# - Explore adding more advanced tools (like **FileSearchTool** or **CodeInterpreterTool**) to provide more specialized info.
# - Evaluate your AI's performance with **azure-ai-evaluation**!
# - Add **OpenTelemetry** or Azure Monitor for deeper insights.
# - Incorporate **function calling** if you want to handle things like advanced calculation or direct data analysis.
#
# #### Let's proceed to [2-code_interpreter.ipynb](2-code_interpreter.ipynb)
#
# Happy (healthy) coding! 💪

# %% [markdown]
# ## 🎯 Summary & Next Steps
#
# Congratulations! You've successfully:
#
# ✅ **Connected to Azure AI Foundry** - Established secure connection using authentication
# ✅ **Created an AI Agent** - Built a specialized Health & Fitness Assistant
# ✅ **Implemented Chat Functionality** - Created functions to interact with the agent
# ✅ **Tested Multiple Scenarios** - Verified the agent works for various health questions
#
# ### Key Concepts Learned
#
# 1. **Azure AI Agent Service** - A managed service for building intelligent AI assistants
# 2. **Threads** - Conversation sessions that maintain context between messages
# 3. **Runs** - Agent processing operations that handle user queries and generate responses
# 4. **Messages** - Individual communications between users and agents
#
# ### What's Next?
#
# This was just the beginning! In the next notebooks, you'll learn about:
#
# - **Code Interpreter** - Agents that can write and execute code
# - **File Search** - Agents that can search through documents
# - **Bing Grounding** - Agents with real-time web search capabilities
# - **AI Search Integration** - Agents connected to your knowledge bases
# - **Azure Functions** - Agents that can trigger actions and workflows
#
# ### 🔧 Key Takeaways
#
# - The **`create_thread_and_process_run()`** method is the simplest way to interact with agents
# - Agents automatically maintain conversation context within threads
# - The agent provides responsible AI disclaimers for health advice
# - Error handling is crucial when working with AI services
#
# Ready to explore more advanced agent capabilities? Continue with the next notebook! 🚀
